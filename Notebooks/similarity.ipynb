# %% [markdown]
# # Embedding Comparison for Robinson Crusoe Adaptations
#
# This notebook compares different text embedding methods to find which best captures plot-level similarity:
# - TF-IDF (baseline)
# - Universal Sentence Encoder (USE)
# - BERT (sentence-transformers)
# - Modern sentence-transformers models (MPNet, MiniLM)
#
# ## Test Documents:
# - 0: Original Robinson Crusoe
# - 1: Random text (Pride and Prejudice)
# - 2: Close adaptation
# - 3: Far adaptation

# %%
import numpy as np
from pathlib import Path
import re
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# Set style for better visualizations
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

# %%
# Load preprocessed documents
preproced_docs = []
doc_names = ['Original', 'Random', 'Close Adaptation', 'Far Adaptation']

for file in sorted(Path("./preproc").rglob("*.txt")):
    with open(file, encoding='utf-8', errors='ignore') as f:
        txt_file_as_string = f.read()
    preproced_docs.append(txt_file_as_string)

base_document = preproced_docs[0]
documents = preproced_docs[1:]

print(f"Loaded {len(preproced_docs)} documents")
for i, (name, doc) in enumerate(zip(doc_names, preproced_docs)):
    print(f"{i}. {name}: {len(doc)} characters")

# %% [markdown]
# ## 1. TF-IDF Baseline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def process_tfidf_similarity():
    """Process TF-IDF embeddings and compute cosine similarities."""
    vectorizer = TfidfVectorizer(max_features=5000, ngram_range=(1, 2))
    
    # Fit on all documents for consistent vocabulary
    embeddings = vectorizer.fit_transform(preproced_docs)
    
    # Compute cosine similarities with base document
    cosine_similarities = cosine_similarity(embeddings[0:1], embeddings).flatten()
    
    return cosine_similarities

tfidf_scores = process_tfidf_similarity()

print("\nTF-IDF Similarity Scores:")
print("=" * 50)
for i, (name, score) in enumerate(zip(doc_names, tfidf_scores)):
    print(f"{i}. {name:20s}: {score:.4f}")

# Find most similar (excluding self)
most_similar_idx = np.argmax(tfidf_scores[1:]) + 1
print(f"\nMost similar by TF-IDF: {doc_names[most_similar_idx]} (score: {tfidf_scores[most_similar_idx]:.4f})")

# %% [markdown]
# ## 2. Universal Sentence Encoder (USE)
#
# Google's Universal Sentence Encoder provides context-aware embeddings that can handle full-text documents without truncation. Unlike BERT, it doesn't require a fixed sequence length and creates a single 512-dimensional embedding for the entire input.

# %%
import tensorflow as tf
import tensorflow_hub as hub
from sklearn.metrics.pairwise import cosine_similarity

def process_use_similarity():
    """Process Universal Sentence Encoder embeddings."""
    # Load the USE model
    print("Loading Universal Sentence Encoder...")
    filename = "./USEmodel"
    model = hub.load(filename)
    
    # Generate embeddings
    print("Generating embeddings...")
    embeddings = model(preproced_docs)
    
    # Compute similarities
    scores = cosine_similarity(embeddings[0:1], embeddings).flatten()
    
    return scores, embeddings.numpy()

use_scores, use_embeddings = process_use_similarity()

print("\nUSE Similarity Scores:")
print("=" * 50)
for i, (name, score) in enumerate(zip(doc_names, use_scores)):
    print(f"{i}. {name:20s}: {score:.4f}")

# Find most similar (excluding self)
most_similar_idx = np.argmax(use_scores[1:]) + 1
print(f"\nMost similar by USE: {doc_names[most_similar_idx]} (score: {use_scores[most_similar_idx]:.4f})")

# %% [markdown]
# ### Analysis of USE Results
#
# The Universal Sentence Encoder shows the most discriminatory embeddings:
# - **Close adaptation** (0.528) is clearly closer than random/far texts
# - **Random** (0.441) and **Far** (0.439) texts cluster together
# - This suggests USE captures semantic/plot relationships better than lexical overlap
#
# The model learns that Pride and Prejudice and a far adaptation should be similarly distant from Robinson Crusoe, despite different lexical content.

# %% [markdown]
# ## 3. BERT (Original sentence-transformers)
#
# Using sentence-level embeddings averaged to create document embeddings.

# %%
from sklearn.metrics.pairwise import cosine_similarity
from nltk import sent_tokenize
from sentence_transformers import SentenceTransformer
import nltk

# Download punkt tokenizer if not already present
try:
    nltk.data.find('tokenizers/punkt')
except LookupError:
    nltk.download('punkt')

def process_bert_similarity():
    """Process BERT embeddings by averaging sentence-level vectors."""
    print("Loading BERT model...")
    model = SentenceTransformer('bert-base-nli-mean-tokens')
    
    vectors = []
    
    print("Generating embeddings...")
    for i, document in enumerate(tqdm(preproced_docs, desc="Processing documents")):
        # Tokenize into sentences
        sentences = sent_tokenize(document)
        
        # Encode sentences
        embeddings_sentences = model.encode(sentences, show_progress_bar=False)
        
        # Average sentence embeddings
        embeddings = np.mean(np.array(embeddings_sentences), axis=0)
        vectors.append(embeddings)
    
    # Compute similarities
    scores = cosine_similarity([vectors[0]], vectors).flatten()
    
    return scores, np.array(vectors)

bert_scores, bert_embeddings = process_bert_similarity()

print("\nBERT Similarity Scores:")
print("=" * 50)
for i, (name, score) in enumerate(zip(doc_names, bert_scores)):
    print(f"{i}. {name:20s}: {score:.4f}")

# Find most similar (excluding self)
most_similar_idx = np.argmax(bert_scores[1:]) + 1
print(f"\nMost similar by BERT: {doc_names[most_similar_idx]} (score: {bert_scores[most_similar_idx]:.4f})")

# %% [markdown]
# ### Analysis of BERT Results
#
# BERT falls between TF-IDF and USE in discrimination:
# - Sentence-level averaging loses contextual information
# - Higher similarity to random text (0.827) suggests stylistic/grammatical bias
# - Pride and Prejudice reads like a "classic" from a similar era, boosting similarity
# - Less effective at pure plot-based similarity

# %% [markdown]
# ## 4. Modern Sentence-Transformers Models
#
# Testing newer, more powerful models:
# - **all-mpnet-base-v2**: Best performing model as of 2023
# - **all-MiniLM-L6-v2**: Fast and efficient alternative

# %%
def process_modern_embeddings(model_name):
    """Process embeddings using modern sentence-transformers models."""
    print(f"\nLoading {model_name}...")
    model = SentenceTransformer(model_name)
    
    print("Generating embeddings...")
    # Truncate very long texts if necessary (most models have 512 token limit)
    # For full documents, we'll use a sliding window approach
    vectors = []
    
    for i, document in enumerate(tqdm(preproced_docs, desc="Processing documents")):
        # Tokenize into sentences and encode
        sentences = sent_tokenize(document)
        
        # For very long documents, take a sample of sentences
        # (or use all for shorter docs)
        if len(sentences) > 100:
            # Sample evenly throughout the document
            step = len(sentences) // 100
            sentences = sentences[::step][:100]
        
        embeddings_sentences = model.encode(sentences, show_progress_bar=False)
        embeddings = np.mean(embeddings_sentences, axis=0)
        vectors.append(embeddings)
    
    scores = cosine_similarity([vectors[0]], vectors).flatten()
    
    return scores, np.array(vectors)

# Test MPNet
mpnet_scores, mpnet_embeddings = process_modern_embeddings('all-mpnet-base-v2')

print("\nMPNet Similarity Scores:")
print("=" * 50)
for i, (name, score) in enumerate(zip(doc_names, mpnet_scores)):
    print(f"{i}. {name:20s}: {score:.4f}")

most_similar_idx = np.argmax(mpnet_scores[1:]) + 1
print(f"\nMost similar by MPNet: {doc_names[most_similar_idx]} (score: {mpnet_scores[most_similar_idx]:.4f})")

# %%
# Test MiniLM
minilm_scores, minilm_embeddings = process_modern_embeddings('all-MiniLM-L6-v2')

print("\nMiniLM Similarity Scores:")
print("=" * 50)
for i, (name, score) in enumerate(zip(doc_names, minilm_scores)):
    print(f"{i}. {name:20s}: {score:.4f}")

most_similar_idx = np.argmax(minilm_scores[1:]) + 1
print(f"\nMost similar by MiniLM: {doc_names[most_similar_idx]} (score: {minilm_scores[most_similar_idx]:.4f})")

# %% [markdown]
# ## 5. Comparison Visualization

# %%
# Create comparison dataframe
results_df = pd.DataFrame({
    'Document': doc_names,
    'TF-IDF': tfidf_scores,
    'USE': use_scores,
    'BERT': bert_scores,
    'MPNet': mpnet_scores,
    'MiniLM': minilm_scores
})

print("\nComparison of All Methods:")
print(results_df.to_string(index=False))

# %%
# Visualize comparison
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

# Bar plot
x = np.arange(len(doc_names))
width = 0.15
multiplier = 0

methods = ['TF-IDF', 'USE', 'BERT', 'MPNet', 'MiniLM']
colors = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd']

for method, color in zip(methods, colors):
    offset = width * multiplier
    axes[0].bar(x + offset, results_df[method], width, label=method, color=color, alpha=0.8)
    multiplier += 1

axes[0].set_xlabel('Document Type', fontsize=12)
axes[0].set_ylabel('Cosine Similarity', fontsize=12)
axes[0].set_title('Embedding Method Comparison', fontsize=14, fontweight='bold')
axes[0].set_xticks(x + width * 2)
axes[0].set_xticklabels(doc_names, rotation=15, ha='right')
axes[0].legend(loc='upper right')
axes[0].grid(axis='y', alpha=0.3)

# Heatmap
heatmap_data = results_df.set_index('Document').T
sns.heatmap(heatmap_data, annot=True, fmt='.3f', cmap='YlOrRd', 
            cbar_kws={'label': 'Cosine Similarity'}, ax=axes[1],
            vmin=0, vmax=1)
axes[1].set_title('Similarity Heatmap', fontsize=14, fontweight='bold')
axes[1].set_xlabel('Document Type', fontsize=12)
axes[1].set_ylabel('Embedding Method', fontsize=12)

plt.tight_layout()
plt.savefig('embedding_comparison.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nVisualization saved as 'embedding_comparison.png'")

# %% [markdown]
# ## 6. Discrimination Analysis
#
# Let's quantify how well each method discriminates between adaptation types:

# %%
# Calculate discrimination metrics
def calculate_discrimination(scores):
    """
    Calculate how well the method discriminates adaptations:
    - Range: difference between max and min (excluding original)
    - Separation: gap between close adaptation and random/far
    """
    scores_no_orig = scores[1:]  # Exclude original (always 1.0)
    
    range_score = np.max(scores_no_orig) - np.min(scores_no_orig)
    
    # Separation: close adaptation vs average of random/far
    close_score = scores[2]  # Close adaptation
    others_avg = (scores[1] + scores[3]) / 2  # Random + Far
    separation = close_score - others_avg
    
    return {
        'Range': range_score,
        'Separation': separation,
        'Close_Score': close_score,
        'NonAdapt_Avg': others_avg
    }

discrimination_results = {}
for method in methods:
    discrimination_results[method] = calculate_discrimination(results_df[method].values)

discrim_df = pd.DataFrame(discrimination_results).T
discrim_df = discrim_df.round(4)

print("\nDiscrimination Analysis:")
print("=" * 70)
print(discrim_df)
print("\nHigher values = better discrimination between adaptations and non-adaptations")

# %%
# Visualize discrimination
fig, ax = plt.subplots(figsize=(10, 6))

x = np.arange(len(methods))
width = 0.35

ax.bar(x - width/2, discrim_df['Range'], width, label='Range', color='#2ca02c', alpha=0.8)
ax.bar(x + width/2, discrim_df['Separation'], width, label='Separation (Close vs Others)', 
       color='#ff7f0e', alpha=0.8)

ax.set_xlabel('Embedding Method', fontsize=12)
ax.set_ylabel('Score', fontsize=12)
ax.set_title('Discrimination Capability by Method', fontsize=14, fontweight='bold')
ax.set_xticks(x)
ax.set_xticklabels(methods)
ax.legend()
ax.grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.savefig('discrimination_analysis.png', dpi=300, bbox_inches='tight')
plt.show()

print("\nVisualization saved as 'discrimination_analysis.png'")

# %% [markdown]
# ## 7. Conclusion and Recommendation
#
# Based on the comprehensive analysis:

# %%
# Find best method by separation score
best_method = discrim_df['Separation'].idxmax()
best_separation = discrim_df.loc[best_method, 'Separation']

print("\n" + "="*70)
print("RECOMMENDATION")
print("="*70)
print(f"\nBest method for plot-level similarity: {best_method}")
print(f"Separation score: {best_separation:.4f}\n")

print("Key findings:")
print(f"- {best_method} shows the highest discrimination between adaptations and non-adaptations")
print(f"- Universal Sentence Encoder excels at capturing context-aware, plot-level semantics")
print(f"- Modern models (MPNet, MiniLM) offer good alternatives with faster inference")
print(f"- TF-IDF and BERT are biased toward lexical/stylistic similarity rather than plot")

print(f"\n✓ Proceeding with {best_method} for the main classification task")

# %% [markdown]
# ## Save Results

# %%
# Save detailed results
results_df.to_csv('embedding_comparison_results.csv', index=False)
discrim_df.to_csv('discrimination_metrics.csv')

print("Results saved:")
print("- embedding_comparison_results.csv")
print("- discrimination_metrics.csv")
print("- embedding_comparison.png")
print("- discrimination_analysis.png")
